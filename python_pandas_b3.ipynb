# %% [markdown]
# <a href="https://colab.research.google.com/github/krigor-cintra/Pandas/blob/main/python_pandas_b3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importação das bibliotecas

# %%
import pandas as pd
import numpy as np
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# Criação de um df ( Dataframe) com todas as plainlhas extaidas sem duplicidades

# %%
dataframe_2021 = pd.read_excel('/dataframe/movimentacao-2021-01-01-a-2021-12-31.xlsx')
dataframe_2022 = pd.read_excel('/dataframe/movimentacao-2022-01-01-a-2022-12-31.xlsx')
dataframe_2023 = pd.read_excel('/dataframe/movimentacao-2022-01-01-a-2022-12-31.xlsx')

# %% [markdown]
# Arquivos

# %%
df = pd.concat([dataframe_2021, dataframe_2022, dataframe_2023], axis=0, ignore_index=True, verify_integrity=True)
df=df.drop_duplicates() ##Forma de eliminar duplicadas, simples levando em consideração a quantidade de dados
df.to_excel('dataframme.xlsx', index=False) #transformando em excel o dataframe criado ( junção dos 3 df extraidos da b3)

# %% [markdown]
# Criando uma nova column apartir da coluna produto, para obter o papel da ação

# %%
df["Código"]= df["Produto"].str.split(" ").str.get(0) 
#Utilizando a coluna produto, na qual tem o codigo do papale e nome obtive uma coluna com somente o codigo

# %%
df[(df["Código"].str.len() >=6) & (df["Movimentação"] != "Rendimento") & (df["Movimentação"] !=  "Dividendo")]
# Out:
#     Entrada/Saída        Data                           Movimentação  \
# 0         Credito  10/12/2021             Transferência - Liquidação
# 13        Credito  09/12/2022                          Transferência
# 15        Credito  06/12/2022                            Atualização
# 17        Credito  05/12/2022            Juros Sobre Capital Próprio
# 26        Credito  22/11/2022             Transferência - Liquidação
# 34         Debito  28/10/2022  Direitos de Subscrição - Não Exercido
# 35         Debito  28/10/2022                   Recibo de Subscrição
# 36        Credito  28/10/2022                   Recibo de Subscrição
# 38        Credito  27/10/2022                     Cessão de Direitos
# 39         Debito  27/10/2022        Cessão de Direitos - Solicitada
# 40         Debito  27/10/2022              Solicitação de Subscrição
# 44        Credito  20/10/2022             Transferência - Liquidação
# 45        Credito  20/10/2022             Transferência - Liquidação
# 48        Credito  17/10/2022                  Direito de Subscrição
# 51        Credito  13/10/2022             Transferência - Liquidação
# 58        Credito  27/09/2022             Transferência - Liquidação
# 62        Credito  20/09/2022             Transferência - Liquidação
# 63        Credito  20/09/2022             Transferência - Liquidação
# 65        Credito  20/09/2022             Transferência - Liquidação
# 66        Credito  16/09/2022             Transferência - Liquidação
# 67        Credito  16/09/2022             Transferência - Liquidação
# 68        Credito  16/09/2022             Transferência - Liquidação
# 69        Credito  16/09/2022             Transferência - Liquidação
# 71         Debito  13/09/2022                                  Venda
# 74        Credito  06/09/2022             Transferência - Liquidação
# 76        Credito  02/09/2022             Transferência - Liquidação
# 78        Credito  01/09/2022             Transferência - Liquidação
# 79        Credito  01/09/2022             Transferência - Liquidação
# 82        Credito  23/08/2022             Transferência - Liquidação
# 83        Credito  26/07/2022                                 Compra
# 84        Credito  13/07/2022                                 Compra
# 85        Credito  13/07/2022                                 Compra
# 86        Credito  01/07/2022                                 Compra
# 87        Credito  01/07/2022                                 Compra
# 88        Credito  30/05/2022                                 Compra
# 89        Credito  30/05/2022                                 Compra
# 90        Credito  02/05/2022                                 Compra
# 91        Credito  02/05/2022                                 Compra
# 92        Credito  19/04/2022                                 Compra
# 93        Credito  19/04/2022                                 Compra
# 38                                     INTER DTVM LTDA        2.00
# 39                                     INTER DTVM LTDA        2.00
# 40                                     INTER DTVM LTDA        2.00
# 44                                     INTER DTVM LTDA        3.00
# 45                                     INTER DTVM LTDA        1.00
# 48   INTER DISTRIBUIDORA DE TITULOS E VALORES MOBIL...        4.00
# 51                                     INTER DTVM LTDA        1.00
# 58                                     INTER DTVM LTDA        1.00
# 62                                     INTER DTVM LTDA       10.00
# 63                                     INTER DTVM LTDA       10.00
# 65                                     INTER DTVM LTDA        4.00
# 66                                     INTER DTVM LTDA        3.00
# 67                                     INTER DTVM LTDA        6.00
# 68                                     INTER DTVM LTDA        4.00
# 69                                     INTER DTVM LTDA        6.00
# 71                                  SANTANDER CCVM S/A        3.98
# 74                                     INTER DTVM LTDA        1.00
# 76                                     INTER DTVM LTDA       10.00
# 78                                     INTER DTVM LTDA        3.00
# 79                                     INTER DTVM LTDA        6.00
# 82                                     INTER DTVM LTDA        2.00
# 83   SANTANDER CORRETORA DE CAMBIO E VALORES MOBILI...        3.98
# 84   SANTANDER CORRETORA DE CAMBIO E VALORES MOBILI...        0.04
# 85   SANTANDER CORRETORA DE CAMBIO E VALORES MOBILI...        0.04
# 86   SANTANDER CORRETORA DE CAMBIO E VALORES MOBILI...        0.05
# 87   SANTANDER CORRETORA DE CAMBIO E VALORES MOBILI...        0.12
# 88   SANTANDER CORRETORA DE CAMBIO E VALORES MOBILI...        0.02
# 89   SANTANDER CORRETORA DE CAMBIO E VALORES MOBILI...        0.03
# 90   SANTANDER CORRETORA DE CAMBIO E VALORES MOBILI...        0.15
# 91   SANTANDER CORRETORA DE CAMBIO E VALORES MOBILI...        0.25
# 92   SANTANDER CORRETORA DE CAMBIO E VALORES MOBILI...        0.01
# 93   SANTANDER CORRETORA DE CAMBIO E VALORES MOBILI...        0.02
# 94   SANTANDER CORRETORA DE CAMBIO E VALORES MOBILI...        0.01
# 95   SANTANDER CORRETORA DE CAMBIO E VALORES MOBILI...        0.03
# 96   SANTANDER CORRETORA DE CAMBIO E VALORES MOBILI...        0.01
# 97   SANTANDER CORRETORA DE CAMBIO E VALORES MOBILI...        0.02
# 98   SANTANDER CORRETORA DE CAMBIO E VALORES MOBILI...        1.07
# 99   SANTANDER CORRETORA DE CAMBIO E VALORES MOBILI...        0.02
# 100  SANTANDER CORRETORA DE CAMBIO E VALORES MOBILI...        0.34
#
#     Preço unitário Valor da Operação   Código
# 0             8.36             25.08   NUBR33
# 13               -                 -   NUBR33
# 15               -                 -   VRTA11
# 17             0.6               5.1   TAEE11
# 26           27.89            167.34   SANB11
# 34               -                 -   VRTA12
# 35               -                 -   VRTA13
# 36               -                 -   VRTA13
# 38               -                 -   VRTA12
# 39               -                 -   VRTA12
# 40               -                 -   VRTA12
# 44           78.18            234.54   CXCO11
# 45            91.6              91.6   JSAF11
# 48               -                 -   VRTA12
# 51            78.4              78.4   CXCO11
# 58           94.18             94.18   MORC11
# 62          101.91            1019.1   IRDM11
# 63           95.49             954.9   MORC11
# 65           94.93            379.72   VRTA11
# 66           94.75            284.25   HABT11
# 67          101.56            609.36   IRDM11
# 68            95.5               382   MORC11
# 69           91.41            548.46   RECR11
# 71          914.55           3639.91  Tesouro
# 74           74.48             74.48   MORE11
# 76           41.48             414.8   TAEE11
# 78            96.3             288.9   HABT11
# 79           93.99            563.94   VRTA11
# 82           94.55             189.1   MORC11
# 83          822.72           3274.43  Tesouro
# 84         3137.49             125.5  Tesouro
# 85         1842.33             73.69  Tesouro
# 86         3170.75            158.54  Tesouro
# 87         1913.78            229.65  Tesouro
# 88         3169.38             63.39  Tesouro
# 89         1942.11             58.26  Tesouro
# 90         3145.94            471.89  Tesouro
# 91         1932.24            483.06  Tesouro
# 92         3115.77             31.16  Tesouro
# 93         1908.83             38.18  Tesouro
# 94         3041.72             30.42  Tesouro
# 95         1850.92             55.53  Tesouro
# 96         3037.98             30.38  Tesouro
# 97         1862.08             37.24  Tesouro
# 98         1878.71           2010.22  Tesouro
# 99         3009.11             60.18  Tesouro
# 100        3010.44           1023.55  Tesouro

# %% [markdown]
# Criação de uma dataframe que contem todos os recebimentos ( jpc, dividendo, rendimento)

# %%
df_recebimento= df[(df["Movimentação"] =="Juros Sobre Capital Próprio") | (df["Movimentação"] =="Dividendo") | (df["Movimentação"] =="Rendimento")]
